# %% [markdown]
# # Python + Pandas

# %% [markdown]
# Jednoduchý příklad použití [pandas](https://pandas.pydata.org) Python modulu. Nejprve provedeme potřebné importy.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Potom vytvoříme čtyři náhodné procházky a uložíme si je jako `DataFrame`.

# %%
ts = pd.DataFrame(np.random.randn(1000, 4), columns=list('ABCD')).cumsum()
ts.head()
# Out:
#           A         B         C         D
# 0 -1.076881 -0.506557  0.593630  0.430265
# 1 -1.380447 -0.100036 -0.369298  0.705425
# 2 -2.037066 -0.895943 -3.137027 -0.394558
# 3 -1.611084 -0.761858 -3.575112  0.246070
# 4 -0.619003 -0.011121 -5.996173 -0.204945

# %% [markdown]
# A konečně vytvoříme jejich graf.

# %%
ts.plot()

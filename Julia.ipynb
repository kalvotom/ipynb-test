# %% [markdown]
# # Julia

# %% [markdown]
# ## Grafy

# %% [markdown]
# Jednoduchá ukázka Julia jádra s tvorbou grafíku.

# %%
using Plots

# %%
x    = 1:1000
walk = cumsum(randn(1000, 4), dims=1)
plot(x, walk)

# %% [markdown]
# ## Tabulky

# %%
using DataFrames

# %% [markdown]
# Pár náhodných čísel a hodnot funkce $\sin(x)$.

# %%
df = DataFrame(columnA=rand(10), columnB=map(sin, 1:10))
# Out:
# 10×2 DataFrame
# │ Row │ columnA   │ columnB   │
# │     │ Float64   │ Float64   │
# ├─────┼───────────┼───────────┤
# │ 1   │ 0.698285  │ 0.841471  │
# │ 2   │ 0.98799   │ 0.909297  │
# │ 3   │ 0.439587  │ 0.14112   │
# │ 4   │ 0.112089  │ -0.756802 │
# │ 5   │ 0.329309  │ -0.958924 │
# │ 6   │ 0.0367864 │ -0.279415 │
# │ 7   │ 0.834877  │ 0.656987  │
# │ 8   │ 0.753249  │ 0.989358  │
# │ 9   │ 0.0113729 │ 0.412118  │
# │ 10  │ 0.124376  │ -0.544021 │
